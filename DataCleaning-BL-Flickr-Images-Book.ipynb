# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('C:/Users/kongy/Documents/Python Scripts/Datasets/BL-Flickr-Images-Book.csv')

# %%
data.head(10)
# Out:
#    Identifier              Edition Statement  \
# 0         206                            NaN
# 1         216                            NaN
# 2         218                            NaN
# 3         472                            NaN
# 4         480   A new edition, revised, etc.
# 5         481  Fourth edition, revised, etc.
# 6         519                            NaN
# 7         667                            NaN
# 8         874                            NaN
# 9        1143                            NaN
#
#                   Place of Publication Date of Publication  \
# 0                               London         1879 [1878]
# 1             London; Virtue & Yorston                1868
# 2                               London                1869
# 3                               London                1851
# 4                               London                1857
# 5                               London                1875
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8287 entries, 0 to 8286
# Data columns (total 15 columns):
# Identifier                8287 non-null int64
# Edition Statement         773 non-null object
# Place of Publication      8287 non-null object
# Date of Publication       8106 non-null object
# Publisher                 4092 non-null object
# Title                     8287 non-null object
# Author                    6509 non-null object
# Contributors              8287 non-null object
# Corporate Author          0 non-null float64
# Corporate Contributors    0 non-null float64
# Former owner              1 non-null object
# Engraver                  0 non-null float64
# Issuance type             8287 non-null object
# Flickr URL                8287 non-null object
# Shelfmarks                8287 non-null object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 971.2+ KB

# %%
#Delete all-null Columns and Rows
data=data.dropna(axis=1,how='all')
data=data.dropna(how='all')

# %%
#Make Sure all entries are unique
data['Identifier'].is_unique
# Out:
# True

# %%
#Replace the existing index with Identifier
data.set_index('Identifier',inplace=True)
data.head(10)
# Out:
#                         Edition Statement  \
# Identifier
# 206                                   NaN
# 216                                   NaN
# 218                                   NaN
# 472                                   NaN
# 480          A new edition, revised, etc.
# 481         Fourth edition, revised, etc.
# 519                                   NaN
# 667                                   NaN
# 874                                   NaN
# 1143                                  NaN
#
#                            Place of Publication Date of Publication  \
# Identifier
# 206                                      London         1879 [1878]
# 216                    London; Virtue & Yorston                1868
# 218                                      London                1869
# 472                                      London                1851
# 480                                      London                1857
# ...

# %%
data.get_dtype_counts()
# Out:
# object    11
# dtype: int64

# %%
data.loc[1143:,'Date of Publication'].head(10)
# Out:
# Identifier
# 1143           1679
# 1280           1802
# 1808           1859
# 1905           1888
# 1929    1839, 38-54
# 2836           1897
# 2854           1865
# 2956        1860-63
# 2957           1873
# 3017           1866
# Name: Date of Publication, dtype: object

# %%
regex = r'^(\d{4})'

# %%
data.loc[1143:,'Date of Publication'].head(10)
# Out:
# Identifier
# 1143           1679
# 1280           1802
# 1808           1859
# 1905           1888
# 1929    1839, 38-54
# 2836           1897
# 2854           1865
# 2956        1860-63
# 2957           1873
# 3017           1866
# Name: Date of Publication, dtype: object

# %%
data['Date of Publication'].isnull().sum()
# Out:
# 181

# %%
data['Place of Publication'].head(10)
# Out:
# Identifier
# 206                                  London
# 216                London; Virtue & Yorston
# 218                                  London
# 472                                  London
# 480                                  London
# 481                                  London
# 519                                  London
# 667     pp. 40. G. Bryan & Co: Oxford, 1898
# 874                                 London]
# 1143                                 London
# Name: Place of Publication, dtype: object

# %%
pub=data['Place of Publication']
london=pub.str.contains('London')
oxford=pub.str.contains('Oxford')
london[:10]
# Out:
# Identifier
# 206      True
# 216      True
# 218      True
# 472      True
# 480      True
# 481      True
# 519      True
# 667     False
# 874      True
# 1143     True
# Name: Place of Publication, dtype: bool

# %%
data['Place of Publication']=np.where(london,'London',np.where(oxford,'Oxford',pub.str.replace(' ','-')))
data['Place of Publication'].head(10)
# Out:
# Identifier
# 206     London
# 216     London
# 218     London
# 472     London
# 480     London
# 481     London
# 519     London
# 667     Oxford
# 874     London
# 1143    London
# Name: Place of Publication, dtype: object

# %%
data['Place of Publication'].unique()
# Out:
# array(['London', 'Oxford', 'Coventry', ..., 'MeridadeYucatan',
#        'Москва,1860', 'Moskwa'], dtype=object)
